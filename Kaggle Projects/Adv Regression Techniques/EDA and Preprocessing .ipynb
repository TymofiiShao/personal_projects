# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sw
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Тимофей\AppData\Roaming\Python\Python310\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('houses prices train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include=['O'])
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %% [markdown]
# ## Exploring our target value

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['SalePrice'], kde=True, color='purple')
plt.title('Distribution of Sale Prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['SalePrice'], color='purple', linewidth=2.5)
plt.grid(True, linestyle='-', alpha=0.7)
plt.show()

# %%
numeric_attributes = df.select_dtypes(include=['int64', 'float64']).columns

colors = sns.color_palette('husl', n_colors=len(numeric_attributes))

for i, col in enumerate(numeric_attributes):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    axes[0].set_title(col + ' (Distplot)')
    sns.distplot(df[col], ax=axes[0], color=colors[i])
    axes[1].set_title(col + ' (Scatterplot)')
    sns.scatterplot(y=df['SalePrice'], x=df[col], ax=axes[1], color=colors[i])

plt.show()

# %% [markdown]
# ## Count distirbution of dtypes

# %%
types_counts = df.dtypes.value_counts()
types_counts.plot.pie(autopct=lambda p: '{:.0f}'.format(p * sum(types_counts) / 100)) 
plt.show()

# %%
numeric_features = []
categorical_features = []

for column in df.columns:
    if df[column].dtype in ['int64', 'float64']:
        numeric_features.append(column)
    elif df[column].dtype == 'object':
        categorical_features.append(column)

print("Numeric Features:", numeric_features)
print(125 * '-')
print("Categorical Features:", categorical_features)
# Out:
# Numeric Features: ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
# -----------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Checking for missings

# %%
def count_missings(df):
    missing_values = df.isnull().sum()
    missing_percentage = (missing_values / len(df)) * 100
    missing_df = pd.concat([missing_values, missing_percentage], axis=1)
    missing_df.columns = ['Missing Count', 'Missing %']
    missing_df_sorted = missing_df[missing_df['Missing %'] > 1].sort_values(by='Missing %', ascending=False)
    
    return missing_df_sorted

# %%
def plot_missing_percentage(df):
    missing_values = df.isnull().sum()
    missing_percentage = (missing_values / len(df)) * 100

    plt.figure(figsize=(10, 8)) 
    sns.set(font_scale=1.2) 
    sorted_missings = missing_percentage[missing_percentage > 0.01].sort_values(ascending=True)
    colors = sns.color_palette("husl", len(sorted_missings))
    sorted_missings.plot(kind="barh", color=colors)

    plt.title("Features with the highest percentage of missings")
    plt.xlabel("Percentage of missings")
    plt.ylabel("Features")
    plt.show()

# %%
plot_missing_percentage(df)

# %%
def heatmap(df):
    df_numeric = df.select_dtypes(include=['number'])
    corr = df_numeric.corr()
    highly_corr_features = corr.index[abs(corr["SalePrice"])>0.5]
    plt.figure(figsize=(10,10))
    map = sns.heatmap(df[highly_corr_features].corr(),annot=True,cmap="inferno", fmt='.2f', annot_kws={"color": "white"})

# %%
heatmap(df)

# %% [markdown]
# ## Dropping no need columns

# %%
df = df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence'], axis = 1)

# %%
plot_missing_percentage(df)

# %% [markdown]
# ## Filling missings

# %%
df["MasVnrArea"] = df['MasVnrArea'].mean()
df["LotFrontage"] = df['LotFrontage'].mean()
df["GarageYrBlt"] = df["GarageYrBlt"].fillna(0)

# %%
df['GarageType'] = df['GarageType'].fillna('NA')
df['GarageFinish'] = df['GarageFinish'].fillna('NA')
df['GarageCond'] = df['GarageCond'].fillna('NA')
df['GarageQual'] = df['GarageQual'].fillna('NA')

df['BsmtQual'] = df['BsmtQual'].fillna('NA')
df['BsmtCond'] = df['BsmtCond'].fillna('NA')
df['BsmtExposure'] = df['BsmtExposure'].fillna('NA')
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('NA')
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('NA')

df['Electrical'] = df['Electrical'].fillna('NA')

df['FireplaceQu'] = df['FireplaceQu'].fillna('NA')
df['MasVnrType'] = df['MasVnrType'].fillna('NA')

# %% [markdown]
# ## Some new features

# %%
df['HouseAge'] = df['YrSold'] - df['YearBuilt']
df['HouseRemodelAge'] = df['YrSold'] - df['YearRemodAdd']
df['TotalBaths'] = df['BsmtFullBath'] + df['FullBath'] + 0.5 * (df['BsmtHalfBath'] + df['HalfBath']) 
df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']
df['TotalPorchSF']= (df['OpenPorchSF'] + df['3SsnPorch'] + df['EnclosedPorch'] + df['ScreenPorch'] + df['WoodDeckSF'])
df['hasgarage'] = df['GarageArea'].apply(lambda x: 1 if x > 0 else 0)
df['haspool'] = df['PoolArea'].apply(lambda x: 1 if x > 0 else 0)

# %%
df = df.drop(['YrSold', 'YearBuilt', 'YearRemodAdd', 'BsmtFullBath', 'FullBath', 'BsmtHalfBath', 'HalfBath',
             'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch',
             'WoodDeckSF', 'GarageCars', 'GarageArea', 'PoolArea'], axis = 1)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL    70.049958     8450   Pave      Reg
# 1        2          20       RL    70.049958     9600   Pave      Reg
# 2        3          60       RL    70.049958    11250   Pave      IR1
# 3        4          70       RL    70.049958     9550   Pave      IR1
# 4        5          60       RL    70.049958    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL    70.049958     7917   Pave      Reg
# 1456  1457          20       RL    70.049958    13175   Pave      Reg
# 1457  1458          70       RL    70.049958     9042   Pave      Reg
# 1458  1459          20       RL    70.049958     9717   Pave      Reg
# 1459  1460          20       RL    70.049958     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... SaleType SaleCondition SalePrice  \
# ...

# %% [markdown]
# ## Encoding

# %%
label_encoding_map = {}


features_label_encoding = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                           'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 
                           'Functional', 'FireplaceQu', 'GarageFinish', 'GarageQual', 
                           'GarageCond']


def label_encode(feature):
    unique_categories = df[feature].unique()  
    encoding_map = {category: idx for idx, category in enumerate(unique_categories)}  
    df[feature] = df[feature].map(encoding_map)  
    label_encoding_map[feature] = encoding_map  

for feature in features_label_encoding:
    label_encode(feature)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL    70.049958     8450   Pave      Reg
# 1        2          20       RL    70.049958     9600   Pave      Reg
# 2        3          60       RL    70.049958    11250   Pave      IR1
# 3        4          70       RL    70.049958     9550   Pave      IR1
# 4        5          60       RL    70.049958    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL    70.049958     7917   Pave      Reg
# 1456  1457          20       RL    70.049958    13175   Pave      Reg
# 1457  1458          70       RL    70.049958     9042   Pave      Reg
# 1458  1459          20       RL    70.049958     9717   Pave      Reg
# 1459  1460          20       RL    70.049958     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... SaleType SaleCondition SalePrice  \
# ...

# %%
df = pd.get_dummies(df, columns=['MSZoning', 'Street', 'Utilities', 'LotShape', 'LandContour', 
                                 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 
                                 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 
                                 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 
                                 'Foundation', 'Heating', 'CentralAir', 'Electrical', 
                                 'GarageType', 'PavedDrive', 
                                 'SaleType', 'SaleCondition'], drop_first= True)

# %%
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60    70.049958     8450            7            5
# 1        2          20    70.049958     9600            6            8
# 2        3          60    70.049958    11250            7            5
# 3        4          70    70.049958     9550            7            5
# 4        5          60    70.049958    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60    70.049958     7917            6            5
# 1456  1457          20    70.049958    13175            6            6
# 1457  1458          70    70.049958     9042            7            9
# 1458  1459          20    70.049958     9717            5            6
# 1459  1460          20    70.049958     9937            5            6
#
#       MasVnrArea  ExterQual  ExterCond  BsmtQual  ...  SaleType_ConLI  \
# ...

# %%
count_missings(df)
# Out:
# Empty DataFrame
# Columns: [Missing Count, Missing %]
# Index: []

# %%
types_counts = df.dtypes.value_counts()
types_counts.plot.pie(autopct=lambda p: '{:.0f}'.format(p * sum(types_counts) / 100)) 
plt.show()

# %%
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    median = df[column].median()
    df[column].fillna(median, inplace=True)

# %%
import json

medians = {column: df[column].median() for column in df.select_dtypes(include=['float64', 'int64']).columns}

with open('medians_22_04_2.json', 'w') as file:
    json.dump(medians, file)

# %%
with open('medians_22_04_2.json', 'r') as file:
    loaded_medians = json.load(file)

# %%
loaded_medians
# Out:
# {'Id': 730.5,
#  'MSSubClass': 50.0,
#  'LotFrontage': 70.04995836802665,
#  'LotArea': 9478.5,
#  'OverallQual': 6.0,
#  'OverallCond': 5.0,
#  'MasVnrArea': 103.68526170798899,
#  'ExterQual': 1.0,
#  'ExterCond': 0.0,
#  'BsmtQual': 1.0,
#  'BsmtCond': 0.0,
#  'BsmtExposure': 0.0,
#  'BsmtFinType1': 2.0,
#  'BsmtFinSF1': 383.5,
#  'BsmtFinType2': 0.0,
#  'BsmtFinSF2': 0.0,
#  'BsmtUnfSF': 477.5,
#  'HeatingQC': 0.0,
#  'LowQualFinSF': 0.0,
#  'GrLivArea': 1464.0,
#  'BedroomAbvGr': 3.0,
#  'KitchenAbvGr': 1.0,
#  'KitchenQual': 1.0,
#  'TotRmsAbvGrd': 6.0,
#  'Functional': 0.0,
#  'Fireplaces': 1.0,
#  'FireplaceQu': 1.0,
#  'GarageYrBlt': 1977.0,
#  'GarageFinish': 1.0,
#  'GarageQual': 0.0,
#  'GarageCond': 0.0,
#  'MiscVal': 0.0,
#  'MoSold': 6.0,
#  'SalePrice': 163000.0,
#  'HouseAge': 35.0,
#  'HouseRemodelAge': 14.0,
#  'TotalBaths': 2.0,
#  'TotalSF': 2474.0,
#  'TotalPorchSF': 164.0,
#  'hasgarage': 1.0,
#  'haspool': 0.0}

# %% [raw]
# for column in df_train.select_dtypes(include=['float64', 'int64']).columns:
#     median = df_train[column].median()
#     df_train[column].fillna(median, inplace=True)

# %% [raw]
# import json
#
# # Assume 'medians' is a dictionary containing the median values for your features
# medians = {column: df[column].median() for column in df.select_dtypes(include=['float64', 'int64']).columns}
#
# # Saving medians to a JSON file
# with open('medians_22_04.json', 'w') as file:
#     json.dump(medians, file)

# %% [raw]
# # Loading medians from a JSON file
# with open('medians_22_04.json', 'r') as file:
#     loaded_medians = json.load(file)
